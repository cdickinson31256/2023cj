# %%
# Everything needed in order to get this to look kinda nice
from astropy.io import fits
import matplotlib.pyplot as plt
from photutils.detection import DAOStarFinder as DAO
import numpy as np
from matplotlib.colors import LogNorm
from photutils.aperture import CircularAperture as ca
from astropy.stats import sigma_clipped_stats as scs # from the yt tutoral I found online :3

# %%
# Everything commented out will be either added in later or isn't needed
# Also make sure everything is in the same directory cause I'm too lazy to make it so it works anywhere :3

# This is code that will find and plot sources on Hubble images (mainly for astrometry purposes)
# It will also create tables that lists their coordinates

# %%
# Global Variables

pre_ex = fits.open('wfc3.f350lp.ref_0001.drz_cropped.fits') # The name in the quotes 
                                                            # is the file name for the pre-explosion image

post_ex = fits.open('iey918020_drc_cropped.fits') # Same applies to this one

pre_data = pre_ex[0]

post_data = post_ex[1] # Make sure this one is uses 1 instead of 0 for some reason

img1 = pre_data.data
img2 = post_data.data

img_zoom = img1[0:460, 0:460]
#Using Data from a file for new coordinates

post_sources_matched = np.loadtxt('matched_list.dat', usecols = (0, 1), ndmin= 2)

pre_sources_matched = np.loadtxt('matched_list.dat', usecols= (2, 3), ndmin=2)

sn_pos = np.loadtxt('2023cj_source.dat') #the very first one is the sn pos; the rest are alr known sources

# %%
# Plotting the Images (This is if you don't have Ds9 to look at the pretty images)

#Pre Explosion Image

plt.figure()
plt.imshow(img1, origin = 'lower', norm = LogNorm(), cmap = 'Greys')
plt.colorbar()
plt.show()

# %%
#Post Explosion Image

plt.figure()
plt.imshow(img2, origin = 'lower', norm = LogNorm(), cmap='Greys')
plt.colorbar()
plt.show()

# %%
#Finding the mean, median and standard deviation of each image

#Pre
mean, median, std = scs(img1)

#Post

mean2, median2, std2 = scs(img2)
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]

# %%
# Actually detecting the stars w/ Their table of Coordinates + writing coordinates to region files

#Pre Explosion

daopre = DAO(fwhm = 3.0, threshold = 5.0 * std)

sources1 = daopre(img1-median)

# Writing DS9 Region File
j = open('wfc3.f350lp.ref_0001.drz_cropped_sources.reg', 'w')

x_pos = np.array(sources1['xcentroid'])
y_pos = np.array(sources1['ycentroid'])

x_round = ['%.3f' % x for x in x_pos]
y_round = ['%.3f' % y for y in y_pos]

for i in range (0, len(x_round)):
    j.write('point('+str(x_round[i])+','+str(y_round[i])+')'+' # '+ 'point=boxcircle text={'+str(i)+'} \n')
j.close()

# Exporting Table
for col in sources1.colnames:
    if col not in ('id', 'npix'):
        sources1[col].info.format = '%.2f'
        
sources1.pprint(max_width = 76)
# Out:
#  id xcentroid ycentroid sharpness roundness1 ... sky     peak   flux  mag
# --- --------- --------- --------- ---------- ... ---- --------- ---- -----
#   1     40.11      3.30      0.57       0.02 ... 0.00 111460.93 9.94 -2.49
#   2    949.94      7.25      0.57       0.01 ... 0.00  13552.51 1.16 -0.16
#   3    744.02      9.01      0.61      -0.14 ... 0.00  33247.41 2.83 -1.13
#   4    940.15     12.06      0.60       0.25 ... 0.00  13861.39 1.04 -0.04
#   5   1027.31     12.48      0.60       0.13 ... 0.00  11634.48 1.09 -0.09
#   6    689.79     13.58      0.55       0.19 ... 0.00  13093.08 1.01 -0.01
#   7   1011.97     16.69      0.52      -0.41 ... 0.00  19297.15 1.40 -0.37
#   8    562.03     36.72      0.44       0.15 ... 0.00  18768.99 1.29 -0.28
#   9    918.71     52.02      0.58      -0.54 ... 0.00  12874.89 1.14 -0.14
#  10    531.06     62.14      0.58      -0.28 ... 0.00  25452.36 2.27 -0.89
# ...       ...       ...       ...        ... ...  ...       ...  ...   ...
# 468    877.52   1397.71      0.57      -0.63 ... 0.00  53722.75 2.82 -1.13
# 469    876.16   1400.40      0.47      -0.92 ... 0.00  36081.52 1.55 -0.47
# 470    879.93   1399.81      0.52      -0.59 ... 0.00  45035.44 1.96 -0.73
# 471    752.32   1422.39      0.59       0.31 ... 0.00  27627.70 2.13 -0.82
# 472    761.00   1426.43      0.57       0.03 ... 0.00  71212.83 6.18 -1.98
# 473    158.58   1430.47      0.58      -0.40 ... 0.00  15372.07 1.44 -0.40
# 474    755.05   1430.52      0.56       0.47 ... 0.00  17331.11 1.34 -0.32
# 475    800.95   1437.93      0.56      -0.17 ... 0.00  36526.38 3.20 -1.26
# 476    773.80   1444.14      0.63      -0.11 ... 0.00  44340.29 4.02 -1.51
# 477    720.01   1458.17      0.52       0.05 ... 0.00  56997.01 3.41 -1.33
# 478    581.39   1489.54      0.57      -0.46 ... 0.00  10710.82 1.08 -0.08
# Length = 478 rows

# %%
# # Post Explosion

# # mask = np.zeros(img2.shape, dtype = bool)
# # mask[700:890, 720:770] = True

# daopost = DAO(fwhm = 3.0, threshold = 5.0 * std2)

# sources2 = daopost(img2-median)
# # Writing the Region File
# f = open('iey918020_drc_cropped_fits_sources.reg', 'w')


# x_pos_2 = np.array(sources2['xcentroid'])
# y_pos_2 = np.array(sources2['ycentroid'])

# x2_round = ['%.3f' % x for x in x_pos_2]
# y2_round = ['%.3f' % y for y in y_pos_2 ]

# for i in range (0, len(x2_round)):
#     f.write('point('+str(x2_round[i])+','+str(y2_round[i])+')'+' # '+ 'point=boxcircle text={'+str(i)+'} \n')
# f.close()


# for col in sources2.colnames:
#     if col not in ('id', 'npix'):
#         sources2[col].info.format = '%.3f'

        
# sources2.pprint(max_width = 76)
# Out:
#  id xcentroid ycentroid sharpness ...  sky     peak    flux   mag
# --- --------- --------- --------- ... ----- --------- ------ ------
#   1   984.470    33.464     0.649 ... 0.000 -2299.365  1.659 -0.550
#   2   878.257    38.172     0.864 ... 0.000 -2297.765  9.773 -2.475
#   3   724.006    50.567     0.949 ... 0.000 -2299.331  1.576 -0.494
#   4  1176.132    62.651     0.485 ... 0.000 -2299.296  1.329 -0.309
#   5   649.121    65.864     0.971 ... 0.000 -2296.322 16.429 -3.039
#   6  1372.560    72.596     0.598 ... 0.000 -2298.160  9.411 -2.434
#   7   818.702    79.837     0.774 ... 0.000 -2299.300  1.677 -0.561
#   8  1416.336    88.255     0.874 ... 0.000 -2296.971 14.159 -2.878
#   9   969.697    88.670     0.692 ... 0.000 -2299.224  1.927 -0.712
#  10   997.513    93.453     0.561 ... 0.000 -2299.255  2.168 -0.840
# ...       ...       ...       ... ...   ...       ...    ...    ...
# 347   685.239  1474.731     0.758 ... 0.000 -2299.379  1.152 -0.154
# 348  1138.503  1476.154     0.587 ... 0.000 -2299.106  2.062 -0.786
# 349    19.128  1482.445     0.863 ... 0.000 -2297.942  9.068 -2.394
# 350   482.649  1483.804     0.598 ... 0.000 -2299.252  2.567 -1.023
# 351  1307.575  1483.859     0.504 ... 0.000 -2299.369  1.277 -0.265
# 352  1112.366  1485.126     0.584 ... 0.000 -2299.379  1.187 -0.186
# 353   314.242  1490.485     0.475 ... 0.000 -2299.457  1.086 -0.090
# 354  1145.463  1491.020     0.582 ... 0.000 -2298.967  2.981 -1.186
# 355  1128.229  1492.134     0.629 ... 0.000 -2299.179  1.983 -0.743
# 356  1461.034  1493.900     0.658 ... 0.000 -2299.347  1.179 -0.179
# 357  1123.541  1495.950     0.620 ... 0.000 -2299.285  1.460 -0.411
# Length = 357 rows

# %%
# Graphing circles around each found source from the 2 images
# Pre Explosion

pos1 = np.transpose((sources1['xcentroid'], sources1['ycentroid']))
aps1 = ca(pos1, r = 5.0)
plt.imshow(img1, cmap = 'Greys', origin = 'lower', norm = LogNorm(), interpolation = 'nearest')

aps1.plot(color = 'blue', lw = 0.1, alpha = 1.0);
plt.savefig('wfc3.f350lp.ref_0001.drz_cropped_sources.png', dpi = 500, format = 'png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-f6ebc0c16e6c> in <module>
#       2 # Pre Explosion
#       3
# ----> 4 pos1 = np.transpose((sources1['xcentroid'], sources1['ycentroid']))
#       5 aps1 = ca(pos1, r = 5.0)
#       6 plt.imshow(img1, cmap = 'Greys', origin = 'lower', norm = LogNorm(), interpolation = 'nearest')
#
# NameError: name 'sources1' is not defined

# %%
# Post Explosion

pos2 = np.transpose((sources2['xcentroid'], sources2['ycentroid']))
aps2 = ca(pos2, r = 5.0)
plt.imshow(img2, cmap = 'Greys', origin = 'lower', norm = LogNorm(), interpolation = 'nearest')

aps2.plot(color = 'red', lw = 0.1, alpha = 1.0);
plt.savefig('iey918020_drc_cropped_sources.png', dpi = 500, format = 'png')

# %%
# Finding new coordinates of positions using matched (between both images) xycoords from Source Extractor

daopre_2 = DAO(fwhm = 3.0, threshold = 5.0 * std, xycoords = pre_sources_matched)

sources1_matched = daopre_2(img1-median)

for col in sources1_matched.colnames:
    if col not in ('id', 'npix'):
        sources1_matched[col].info.format = '%.2f'
        
sources1_matched.pprint(max_width = 76)
# Out:
#  id xcentroid ycentroid sharpness roundness1 ... sky    peak   flux  mag
# --- --------- --------- --------- ---------- ... ---- -------- ---- -----
#   1   1442.27    909.92      0.47       0.16 ... 0.00    46.08 0.09  2.60
#   2    813.26   1114.25      0.39       0.77 ... 0.00   939.05 0.10  2.49
#   3    857.99   1060.32      0.22       0.54 ... 0.00  1061.01 0.09  2.64
#   4   1169.93    888.80      0.54       0.57 ... 0.00  2235.06 0.26  1.47
#   5    407.48    280.79      0.47       0.45 ... 0.00  7705.04 0.28  1.38
#   6    286.23    352.21      0.65       0.44 ... 0.00  4743.90 0.21  1.67
#   7    901.70    105.65      0.33       0.76 ... 0.00  8567.69 0.67  0.44
#   8    918.80    156.29      0.53       0.81 ... 0.00  1786.11 0.12  2.29
#   9    114.60    571.20      0.51      -0.69 ... 0.00  5143.20 0.07  2.89
#  10    583.60    447.20      0.42       0.86 ... 0.00 10869.93 0.73  0.34
# ...       ...       ...       ...        ... ...  ...      ...  ...   ...
#  40    351.16    207.23      0.36       0.64 ... 0.00 28175.33 1.59 -0.50
#  41    228.18    279.12      0.35       0.89 ... 0.00  4716.14 0.21  1.68
#  42    687.03    235.32      0.48       0.13 ... 0.00 14754.25 1.16 -0.16
#  43     27.45    561.72      0.40       0.61 ... 0.00 13655.43 0.66  0.44
#  44    747.79    294.52      0.35       0.75 ... 0.00  2789.12 0.03  3.79
#  45    243.54    521.40      0.30       0.98 ... 0.00  7046.33 0.48  0.80
#  46    916.66    271.55      0.34       0.81 ... 0.00 13193.14 0.87  0.15
#  47    564.39    472.72      0.38       0.79 ... 0.00 33092.25 2.52 -1.00
#  48    466.83    495.03      0.36       0.78 ... 0.00 27185.04 1.87 -0.68
#  49    909.80    351.00      0.27       0.42 ... 0.00  1921.50 0.08  2.76
#  50    605.79    488.87      0.56       0.57 ... 0.00  4435.50 0.10  2.48
# Length = 50 rows

# %%
# Post Explosion (Repurposing it for finding the SN Position)

daopost_2 = DAO(fwhm = 3.0, threshold = 5.0 * std2, xycoords = sn_pos)

sources2_matched = daopost_2(img2-median)

for col in sources2_matched.colnames:
    if col not in ('id', 'npix'):
        sources2_matched[col].info.format = '%.3f'

        
sources2_matched.pprint(max_width = 76)
# Out:
#  id xcentroid ycentroid sharpness ...  sky     peak     flux    mag
# --- --------- --------- --------- ... ----- --------- -------- ------
#   1   751.134   750.004     0.463 ... 0.000 -1945.996 1855.752 -8.171
#   2   984.940    33.928     0.649 ... 0.000 -2299.365    1.659 -0.550
#   3   878.514    38.344     0.864 ... 0.000 -2297.765    9.773 -2.475

# %%
# Plotting New Sources
# Pre Explosion

pos1_pre = np.transpose((sources1_matched['xcentroid'], sources1_matched['ycentroid']))
aps1_pre = ca(pos1_pre, r = 5.0)
plt.imshow(img_zoom, cmap = 'Greys', origin = 'lower', norm = LogNorm(), interpolation = 'nearest')

aps1_pre.plot(color = 'blue', lw = 0.1, alpha = 1.0);
plt.savefig('wfc3.f350lp.ref_0001.drz_cropped_matched_sources.png', dpi = 500, format = 'png')

# %%
# Post Explosion

pos2_post = np.transpose((sources2_matched['xcentroid'], sources2_matched['ycentroid']))
aps2_post = ca(pos2_post, r = 5.0)
plt.imshow(img2, cmap = 'Greys', origin = 'lower', norm = LogNorm(), interpolation = 'nearest')

aps2_post.plot(color = 'red', lw = 0.1, alpha = 1.0);
plt.savefig('iey918020_drc_cropped_matched_sources.png', dpi = 500, format = 'png')

# %%
# #Region Files for both Pre and Post Explosions
# #Pre Ex
# k = open('wfc3.f350lp.ref_0001.drz_cropped_matched_sources.reg', 'w')

# x_pos_matched = np.array(sources1_matched['xcentroid'])
# y_pos_matched = np.array(sources1_matched['ycentroid'])

# x_round_matched = ['%.3f' % x for x in x_pos_matched]
# y_round_matched = ['%.3f' % y for y in y_pos_matched]

# for i in range (0, len(x_round_matched)):
#     k.write('point('+str(x_round_matched[i])+','+str(y_round_matched[i])+')'+' # '+ 'point=boxcircle text={'+str(i)+'} \n')
# k.close()

# #Post

# l = open('iey918020_drc_cropped_fits_matched_sources.reg', 'w')


# x_pos_2_matched = np.array(sources2_matched['xcentroid'])
# y_pos_2_matched = np.array(sources2_matched['ycentroid'])

# x2_round_matched = ['%.3f' % x for x in x_pos_2_matched]
# y2_round_matched = ['%.3f' % y for y in y_pos_2_matched]

# for i in range (0, len(x2_round_matched)):
#     l.write('point('+str(x2_round_matched[i])+','+str(y2_round_matched[i])+')'+' # '+ 'point=boxcircle text={'+str(i)+'} \n')
# l.close()

# %%
# Writing the matched list for both

j = open("2023cj.in", 'w')

for i in range(0, len(x2_round_matched)):
    for b in range(0, len(x2_round_matched)):
        j.write(str(x_round_matched[i])+','+str(y_round_matched[i])+','+str(x2_round_matched[b])+','+str(y2_round_matched[b])+' \n')
j.close()  

# This gave me a list with ~1000+ entries; I kinda don't wanna optimize but if this is used please go into it and edit it, thanks <3

# %%
print(post_sources_matched)
# Out:
# [[ 811.2059  110.1345]
#  [ 597.6439  107.2153]
#  [1186.922   136.1698]
#  [ 979.5937  203.8394]
#  [ 399.1138  217.84  ]
#  [ 191.6565  227.7726]
#  [ 798.6978  243.7021]
#  [ 690.5009  235.2025]
#  [ 581.9397  304.8184]
#  [ 226.6813  311.6839]
#  [1204.1659  350.4346]
#  [ 154.6393  350.4197]
#  [ 850.0981  369.2762]
#  [1414.1641  381.7403]
#  [ 607.7587  413.2202]
#  [ 815.6035  427.9172]
#  [ 878.9791  423.7177]
#  [ 771.6579  440.4787]
#  [ 982.576   448.8726]
#  [ 559.3207  452.0462]
#  [ 404.0445  457.7158]
#  [ 780.9839  478.5685]
#  [ 454.8693  482.3528]
#  [  46.4463  479.0323]
#  [ 570.6115  479.8105]
#  [1040.5602 1342.4923]
#  [ 897.6089 1341.0648]
#  [ 366.5479 1384.3575]
#  [ 221.6122 1330.191 ]
#  [1037.1593 1302.1312]
#  [ 356.329  1290.0461]
#  [ 294.5639 1280.7161]
#  [1308.8553 1278.1829]
#  [ 548.8535 1229.2141]
#  [ 739.5554 1223.0039]
#  [1200.775  1225.9115]
#  [ 375.3824 1227.1931]
#  [1005.9904 1206.7133]
#  [1268.4994 1179.7825]
#  [ 138.9253 1176.139 ]
#  [ 478.1065 1123.1274]
#  [ 787.6358 1096.5233]
#  [ 499.0403 1079.9779]
#  [ 845.8052 1070.2335]
#  [ 512.5    1063.382 ]
#  [ 954.736  1061.625 ]
#  [ 276.8683 1044.3539]
#  [1106.6998 1008.389 ]
#  [ 583.7494 1006.8293]
#  [ 435.0958  988.1942]
#  [ 852.5937 1038.7948]
#  [ 746.8873  979.8852]
#  [1319.5159  976.002 ]
#  [ 581.6532  963.9999]
#  [ 185.6606  962.3807]
#  [ 692.213   950.3646]
#  [1464.3945  946.7604]
#  [ 667.371   942.3616]
#  [ 564.8624  932.7273]
#  [1440.0466  904.8417]
#  [ 496.459   892.0455]
#  [1408.8599  888.9896]
#  [ 128.2741  887.403 ]
#  [ 582.2718  891.5659]
#  [ 861.0591  876.7909]
#  [ 377.7518  878.9436]
#  [ 838.8554  861.0925]
#  [ 963.3696  848.804 ]
#  [ 869.0502  838.6577]
#  [ 581.4093  831.1577]
#  [ 468.7927  826.9452]
#  [ 249.0261  836.4872]
#  [ 721.1082  806.3982]
#  [ 818.3864  800.5219]
#  [ 409.1861  789.8085]
#  [ 340.156   777.8497]
#  [1103.9362  772.8417]
#  [ 555.9052  761.0265]
#  [ 479.9894  760.825 ]
#  [1284.8501  747.2079]
#  [1292.3835  781.7332]
#  [ 847.9978  727.9801]
#  [ 655.5414  715.0619]
#  [1378.958   711.6069]
#  [ 723.8827  703.9589]
#  [1216.838   690.0788]
#  [1308.1185  684.9146]
#  [1137.597   676.8108]
#  [1237.2589  662.3071]
#  [ 534.1109  655.4137]
#  [ 348.7867  649.8895]
#  [ 577.2164  639.7316]
#  [1029.4108  641.051 ]
#  [ 997.2466  637.9457]
#  [ 321.1921  604.8282]
#  [1246.2213  589.5782]
#  [1305.1746  588.0047]
#  [1129.5432  580.829 ]
#  [ 529.0139  574.0338]
#  [ 347.0559  555.0809]
#  [ 861.7724  551.8855]
#  [ 884.2599  552.2297]
#  [1400.3947  548.2164]
#  [1292.1589  534.8006]
#  [ 889.8873  533.8809]
#  [1257.9995  529.6613]
#  [ 791.5956  517.9415]
#  [ 395.5913  513.4005]
#  [ 647.6968 1487.6283]
#  [ 983.753  1345.7006]
#  [ 510.5344 1346.2344]
#  [1139.7207 1477.2338]
#  [ 602.6016 1426.7224]
#  [ 753.5061 1356.9941]
#  [ 519.181  1458.4169]
#  [1186.1741 1447.3374]
#  [ 466.8791 1441.8304]
#  [ 309.7832 1384.6259]
#  [ 910.4297 1410.939 ]
#  [1059.0393 1402.3146]
#  [1098.3038 1350.8375]
#  [1022.943  1403.0125]
#  [ 608.4945 1253.9796]
#  [1349.1313 1206.6506]
#  [ 593.9014 1191.0315]
#  [ 945.8484 1249.4781]
#  [1132.4037 1159.8115]
#  [1332.5181 1132.2478]
#  [1365.4489 1146.0198]
#  [ 222.7648 1136.8378]
#  [ 197.3873 1106.2087]
#  [ 407.3004 1129.8879]
#  [ 813.5309 1080.3546]
#  [1096.5994 1111.3337]
#  [ 914.445  1096.9231]
#  [ 686.572  1080.6682]
#  [ 610.4226 1094.8073]
#  [ 278.9303 1084.3337]
#  [ 467.9042 1069.9733]
#  [1401.3619 1066.8431]
#  [ 873.6735 1056.1458]
#  [ 373.4417 1041.7688]
#  [ 795.935  1038.0258]]

# %%
print(pre_sources_matched)
# Out:
# [[ 944.4501 1376.0016]
#  [1153.5145 1282.0452]
#  [ 582.1794 1490.5172]
#  [ 749.5842 1352.7404]
#  [1282.1631 1094.8278]
#  [1461.2152 1014.9445]
#  [ 896.8993 1253.0427]
#  [ 990.106  1185.1509]
#  [1095.4836 1091.1035]
#  [1395.6016  964.2216]
#  [ 503.847  1302.9011]
#  [1443.7649  911.0464]
#  [ 814.8268 1114.4508]
#  [ 295.6488 1353.135 ]
#  [ 997.1304  988.5599]
#  [ 830.2296 1064.3138]
#  [ 740.0264 1111.6361]
#  [ 858.3738 1060.9784]
#  [ 653.8031 1115.1558]
#  [1039.2598  950.5402]
#  [1170.0507  888.4172]
#  [ 850.0617 1006.8685]
#  [1114.5693  861.9414]
#  [1477.5696  735.1764]
#  [1011.209   946.732 ]
#  [ 264.1359  296.7447]
#  [ 407.6848  280.1821]
#  [ 856.1208   42.6448]
#  [1021.3495   39.8816]
#  [ 286.3215  352.9472]
#  [ 904.0235  106.4171]
#  [ 964.5784   91.9471]
#  [  38.3472  481.7953]
#  [ 761.5259  236.1333]
#  [ 558.7134  321.9592]
#  [ 156.0097  474.9883]
#  [ 919.4435  157.17  ]
#  [ 347.755   412.9905]
#  [ 115.9212  570.3513]
#  [1145.5107  106.9821]
#  [ 852.1943  287.2043]
#  [ 584.4281  448.1919]
#  [ 837.1983  361.4321]
#  [ 539.4147  494.8181]
#  [ 837.1983  361.4321]
#  [ 444.1017  544.5804]
#  [1069.5983  299.2833]
#  [ 326.1707  650.4357]
#  [ 801.6475  475.4951]
#  [ 970.3032  423.6755]
#  [ 540.3906  541.9805]
#  [ 665.9231  539.5306]
#  [ 140.8051  745.4027]
#  [ 823.2097  490.4969]
#  [1184.603   340.237 ]
#  [ 734.7615  561.6081]
#  [  20.3935  830.376 ]
#  [ 760.7182  547.9947]
#  [ 848.5784  531.2394]
#  [  61.2499  873.0104]
#  [ 928.5958  524.2345]
#  [  87.1623  856.3682]
#  [1250.9137  403.3669]
#  [ 831.9153  555.0015]
#  [ 600.7737  678.8497]
#  [1035.1586  485.1328]
#  [ 640.5215  676.0479]
#  [ 527.6131  728.1497]
#  [ 587.9903  714.8291]
#  [ 888.1889  598.0523]
#  [ 975.6422  573.6242]
#  [1176.6605  461.571 ]
#  [ 775.559   702.7816]
#  [ 669.0773  730.4228]
#  [1055.0765  565.4641]
#  [1116.0061  568.7698]
#  [ 407.5448  867.7412]
#  [ 932.6696  674.9682]
#  [ 986.092   652.5774]
#  [ 270.0806  958.9726]
#  [ 247.7784  918.2976]
#  [ 666.9728  828.5123]
#  [ 850.9622  746.1752]
#  [ 190.9082 1026.1012]
#  [ 805.1168  798.6787]
#  [ 336.7534  980.3945]
#  [ 275.3278 1009.1194]
#  [ 445.7275  959.0495]
#  [ 339.2271 1016.7208]
#  [1003.4301  738.3787]
#  [1154.8944  689.9788]
#  [ 951.0336  785.3721]
#  [ 537.4802  957.0298]
#  [ 567.6205  947.8741]
#  [1191.212   727.512 ]
#  [ 366.011  1073.4021]
#  [ 300.2639 1129.8931]
#  [ 483.2382 1062.3162]
#  [1020.1826  825.9864]
#  [1193.2317  773.4125]
#  [ 732.3841  970.0772]
#  [ 711.4595  967.5261]
#  [ 234.2363 1183.9723]
#  [ 335.8333 1148.9828]
#  [ 695.5395 1012.9948]
#  [ 348.4125 1152.2343]
#  [ 813.3486  971.6302]
#  [1181.1208  827.8427]
#  [ 563.3831   37.561 ]
#  [ 309.4142  295.128 ]
#  [ 725.1743  127.8456]
#  [ 132.8482  251.969 ]
#  [ 608.6108   60.7935]
#  [ 513.9374  195.6211]
#  [ 690.6634   14.2182]
#  [  78.4734  268.9887]
#  [ 742.3185   21.4635]
#  [ 894.5243   14.6658]
#  [ 351.3647  207.692 ]
#  [ 229.3045  280.3084]
#  [ 203.4453  334.7147]
#  [ 268.9011  276.7974]
#  [ 687.0211  236.479 ]
#  [  29.2189  562.351 ]
#  [ 747.6257  295.2146]
#  [ 364.6991  373.7377]
#  [ 245.1835  522.4013]
#  [  70.4645  630.0091]
#  [  37.1864  624.02  ]
#  [1084.7147  195.9138]
#  [1136.2926  210.9089]
#  [ 918.9858  272.3701]
#  [ 566.1235  473.4692]
#  [ 303.9993  533.5775]
#  [ 468.3982  495.8479]
#  [ 682.7229  423.6859]
#  [ 749.4553  380.401 ]
#  [1039.5823  262.0052]
#  [ 910.382   353.0856]
#  [  36.4792  695.8831]
#  [ 512.9955  525.8647]
#  [ 983.5053  340.0417]
#  [ 606.3839  489.1928]]
